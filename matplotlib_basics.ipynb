# %% [markdown]
# # Importing Libraries

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Basics Of Matplotlib

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2
plt.plot(x_1,y_1)
plt.title("Days Squared Chart")
plt.xlabel("Days")
plt.ylabel("Days Squared")
# Out:
# Text(0, 0.5, 'Days Squared')

# %% [markdown]
# # Print Multiple Plots

# %%
plt.subplot(1,2,1)
plt.plot(x_1,y_1,"r")
plt.subplot(1,2,2)
plt.plot(x_1,y_1,"b")

# %%
fig_1 = plt.figure(figsize = (5,4), dpi = 100)
axes_1 = fig_1.add_axes([0.1,0.1,0.9,0.9])
axes_1.set_xlabel("Days")
axes_1.set_ylabel("Days Squared")
axes_1.set_title("Days Squared Chart")
axes_1.plot(x_1,y_1,label = "x/x^2")
axes_1.plot(y_1,x_1,label = "x^2/x")
axes_1.legend(loc = 0)

axes_2 = fig_1.add_axes([0.45,0.45,0.4,0.3])
axes_2.set_xlabel("Days")
axes_2.set_ylabel("Days Squared")
axes_2.set_title("Days Squared Chart")
axes_2.plot(y_1,x_1,"r")
axes_2.text(0,8,"Message")
# Out:
# Text(0, 8, 'Message')

# %%
fig_3 = plt.figure(figsize = (6,4))
axes_3 = fig_3.add_axes([0,0,1,1])
axes_3.plot(x_1,y_1, color = "navy", alpha = 0.75, lw = 2, ls = "-.", marker = "o", markersize = 7, markerfacecolor = "y", markeredgecolor = "w", markeredgewidth = 0)
axes_3.set_xlim([0,3])
axes_3.set_ylim([0,8])

axes_3.grid(True, color = "0.6", dashes = (5,2,1,1))

# %% [markdown]
# # Ploting Graph From DataSet

# %%
df = pd.read_csv("C:\\Users\\a\\OneDrive\\Desktop\\Project\\DATA\\data\\movies.csv")
df = df.sort_values(by = "Audience score %")
df
# Out:
#                                   Film      Genre  Lead Studio  \
# 2   You Will Meet a Tall Dark Stranger     Comedy  Independent
# 48                        Love Happens      Drama    Universal
# 18                  The Heartbreak Kid     Comedy    Paramount
# 3                         When in Rome     Comedy       Disney
# 55                             Killers     Action    Lionsgate
# ..                                 ...        ...          ...
# 72                 Across the Universe    Romance  Independent
# 43                   Midnight in Paris    Romence         Sony
# 22                             Tangled  Animation       Disney
# 6                               WALL-E  Animation       Disney
# 74                  A Dangerous Method      Drama  Independent
#
#     Audience score %  Profitability  Rotten Tomatoes %  \
# 2                 35       1.211818                 43
# 48                40       2.004444                 18
# 18                41       2.129444                 30
# 3                 44       0.000000                 15
# 55                45       1.245333                 11
# ..               ...            ...                ...
# 72                84       0.652603                 54
# 43                84       8.744706                 93
# 22                88       1.365692                 89
# 6                 89       2.896019                 96
# 74                89       0.448645                 79
#
#     Worldwide Gross (in Million Dollars)  Year
# 2                                  26.66  2010
# 48                                 36.08  2009
# 18                                127.77  2007
# 3                                  43.04  2010
# 55                                 93.40  2010
# ..                                   ...   ...
# 72                                 29.37  2007
# 43                                148.66  2011
# 22                                355.01  2010
# 6                                 521.28  2008
# 74                                  8.97  2011
#
# [77 rows x 8 columns]

# %%
np_arr = df.values
x_2 = np_arr[:,3]
y_2 = np_arr[:,6]
fig_4 = plt.figure(figsize = (6,4))
axes_4 = fig_4.add_axes([0,0,1,1])
axes_4.set_xlabel("Audience Score")
axes_4.set_ylabel("World Wide Gross")
axes_4.set_title("Movies")
axes_4.plot(x_2,y_2)

# %%
x_2.max()
# Out:
# 89

# %%
y_2.max()
# Out:
# 709.82

# %% [markdown]
# # Text Markup

# %%
fig_5 = plt.figure(figsize = (8,6), dpi = 100)
axes_5 = fig_5.add_axes([0.1,0.1,0.9,0.9])

axes_5.text(0,24, r"$ \alpha \beta \theta \rho \iota \omega \zeta \eta \sigma \delta \gamma \psi \chi \kappa $")
axes_5.text(0,22, r"$ \epsilon \upsilon \mu \nu \pi \phi \lambda \hbar \infty $")
axes_5.text(0,20, r"$ \frac{8 - \frac{x}{5}}{8} \sqrt{9} \sin(\pi) \sqrt[3]{8} \acute a \div 5$")
axes_5.text(0,18, r"$ \bar a \hat a \tilde a \vec a \overline {a} \lim_{x \to 2} f(x) = 5$")
axes_5.text(0,16, r"$ \geq \leq  \ne $")

axes_5.plot(x_1,y_1)

# %% [markdown]
# # Histograms

# %%
arr_1 = np.random.randint(1,7,5000)
arr_2 = np.random.randint(1,7,5000)
arr_3 = arr_1 + arr_2

plt.hist(arr_3, bins = 11, density = True, stacked = True)
# Out:
# (array([0.02728, 0.05852, 0.08602, 0.12386, 0.16324, 0.18414, 0.14916,
#         0.11924, 0.09702, 0.06028, 0.03124]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  <BarContainer object of 11 artists>)

# %% [markdown]
# # Bar Charts

# %%
x = ["Nuclear", "Hydro", "Coal", "Gas", "Solar", "Wind", "Other"]
per_1 = [71,10,3,7,2,4,3]
variance = [8,3,1,3,1,2,1]

# plt.bar(x, per_1, color = "purple", yerr = variance)

m_engg = (76,85,86,88,93)
f_engg = (24,15,14,12,7)

spc = np.arange(5)
plt.bar(spc, m_engg, width = 0.45, label = "Male", edgecolor = "k")
plt.bar(spc + 0.45, f_engg, width = 0.45, label = "Female", edgecolor = "k")
plt.xticks(spc+0.45/2, ("Aero","Chem","Civil","Elec","Mech"))
# Out:
# ([<matplotlib.axis.XTick at 0x19ebe6c8b50>,
#   <matplotlib.axis.XTick at 0x19ebe6c8b80>,
#   <matplotlib.axis.XTick at 0x19ebe6c82b0>,
#   <matplotlib.axis.XTick at 0x19ebe6df220>,
#   <matplotlib.axis.XTick at 0x19ebe6df970>],
#  [Text(0.225, 0, 'Aero'),
#   Text(1.225, 0, 'Chem'),
#   Text(2.225, 0, 'Civil'),
#   Text(3.225, 0, 'Elec'),
#   Text(4.225, 0, 'Mech')])

# %% [markdown]
# # 3D Plot

# %%
from mpl_toolkits import mplot3d

fig_6 = plt.figure(figsize = (8,5), dpi = 100)
axes_6 = fig_6.add_axes([0.1,0.1,0.9,0.9], projection = "3d")

z_3 = 15 * np.random.random(100)
x_3 = np.sin(z_3) * np.random.randn(100)
y_3 = np.cos(z_3) * np.random.randn(100)

def get_z(x,y):
    return np.sin(np.sqrt(x**2+y**2))

x_4 = np.linspace(-6, 6, 30)
y_4 = np.linspace(-6, 6, 30)

x_4, y_4  = np.meshgrid(x_4,y_4)
z_4 = get_z(x_4, y_4)

axes_6.view_init(45,55)
# axes_6.contour3D(x_4, y_4, z_4, 100, cmap = "Blues")

axes_6.set_xlabel("x")
axes_6.set_ylabel("y")
axes_6.set_zlabel("z")

# axes_6.plot_wireframe(x_4, y_4, color = "blue")

axes_6.plot_surface(x_4, y_4, z_4, rstride = 1, cstride = 1, cmap = "Blues", edgecolor = None)


# axes_6.scatter3D(x_3,y_3,z_3, c = z_3, cmap = "Blues")

# %% [markdown]
# # Matplotlib Finance

# %%
import mplfinance as mpf

goog_df = pd.read_csv("C:\\Users\\a\\OneDrive\\Desktop\\Project\\DATA\\data\\google.csv", index_col = 0, parse_dates = True)
goog_df.index.name = "Date"
mpf.plot(goog_df, type = "candle")
