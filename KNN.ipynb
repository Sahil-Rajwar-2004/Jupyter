# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import linear_model, preprocessing

# %%
data = pd.read_csv(r"C:\Users\a\OneDrive\Desktop\Project\DATA\data\cars.csv")
data
# Out:
#      buying  maint  door persons lug_boot safety  class
# 0     vhigh  vhigh     2       2    small    med  unacc
# 1     vhigh  vhigh     2       2    small   high  unacc
# 2     vhigh  vhigh     2       2      med    low  unacc
# 3     vhigh  vhigh     2       2      med    med  unacc
# 4     vhigh  vhigh     2       2      med   high  unacc
# ...     ...    ...   ...     ...      ...    ...    ...
# 1722    low    low  more    more      med    med   good
# 1723    low    low  more    more      med   high  vgood
# 1724    low    low  more    more      big    low  unacc
# 1725    low    low  more    more      big    med   good
# 1726    low    low  more    more      big   high  vgood
#
# [1727 rows x 7 columns]

# %%
process = preprocessing.LabelEncoder()
buying = process.fit_transform(list(data["buying"]))
maint = process.fit_transform(list(data["maint"]))
door = process.fit_transform(list(data["door"]))
persons = process.fit_transform(list(data["persons"]))
lug_boot = process.fit_transform(list(data["lug_boot"]))
safety = process.fit_transform(list(data["safety"]))
cls = process.fit_transform(list(data["class"]))

# %%
predict = "class"

# %%
X = list(zip(buying,maint,door,persons,lug_boot,safety))
y = list(cls)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.1)

# %%
model = KNeighborsClassifier(n_neighbors = 5)

# %%
model.fit(X_train,y_train)
accuracy = model.score(X_test,y_test)
accuracy
# Out:
# 0.7536977491961415

# %%
predicted = model.predict(X_test)
names = ["unacc","accuracy","good","vgood"]
for x in range(len(predicted)):
    print(f"Predicted: {names[predicted[x]]}, Data: {X_test[x]}, Actual: {names[y_test[x]]}")
# Out:
# Predicted: good, Data: (2, 1, 3, 2, 1, 2), Actual: accuracy
# Predicted: unacc, Data: (2, 2, 3, 1, 0, 0), Actual: vgood
# Predicted: unacc, Data: (3, 1, 3, 1, 2, 0), Actual: unacc
# Predicted: good, Data: (3, 3, 0, 1, 1, 2), Actual: good
# Predicted: good, Data: (0, 2, 0, 1, 2, 1), Actual: good
# Predicted: good, Data: (3, 0, 0, 2, 0, 1), Actual: good
# Predicted: good, Data: (0, 0, 1, 2, 1, 1), Actual: good
# Predicted: good, Data: (3, 0, 0, 1, 0, 2), Actual: good
# Predicted: good, Data: (0, 1, 3, 1, 2, 2), Actual: good
# Predicted: unacc, Data: (2, 0, 1, 2, 1, 2), Actual: unacc
# Predicted: good, Data: (2, 0, 0, 2, 2, 0), Actual: good
# Predicted: good, Data: (0, 2, 3, 2, 0, 1), Actual: good
# Predicted: good, Data: (3, 2, 3, 1, 0, 1), Actual: good
# Predicted: good, Data: (1, 2, 1, 2, 1, 1), Actual: good
# Predicted: good, Data: (1, 0, 3, 0, 0, 2), Actual: good
# Predicted: good, Data: (1, 2, 1, 0, 0, 1), Actual: good
# Predicted: good, Data: (3, 0, 3, 1, 0, 2), Actual: good
# ...
