# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
main_data = pd.read_csv("C:\\Users\\a\\OneDrive\\Desktop\\Project\\DATA\\data\\elements.csv")
main_data
# Out:
#      AtomicNumber      Element Symbol  AtomicMass  NumberofNeutrons  \
# 0               1     Hydrogen      H       1.007                 0
# 1               2       Helium     He       4.002                 2
# 2               3      Lithium     Li       6.941                 4
# 3               4    Beryllium     Be       9.012                 5
# 4               5        Boron      B      10.811                 6
# ..            ...          ...    ...         ...               ...
# 113           114    Flerovium     Fl     289.000               175
# 114           115    Moscovium     Mc     288.000               173
# 115           116  Livermorium     Lv     292.000               176
# 116           117   Tennessine     Ts     295.000               178
# 117           118    Oganesson     Og     294.000               176
#
#      NumberofProtons  NumberofElectrons  Period  Group       Phase  ...  \
# 0                  1                  1       1    1.0         gas  ...
# ...

# %%
filter_1 = main_data[["AtomicNumber","Symbol","BoilingPoint","MeltingPoint"]]
first = filter_1[filter_1["AtomicNumber"] >= 21].head(10)
second = filter_1[filter_1["AtomicNumber"] >= 39].head(10)
third = filter_1[filter_1["AtomicNumber"] >= 72].head(10)

df_concate = pd.concat([first,second,third])
df_concate
# Out:
#     AtomicNumber Symbol  BoilingPoint  MeltingPoint
# 20            21     Sc        3109.0       1812.15
# 21            22     Ti        3560.0       1933.15
# 22            23      V        3680.0       2175.15
# 23            24     Cr        2944.0       2130.15
# 24            25     Mn        2334.0       1519.15
# 25            26     Fe        3134.0       1808.15
# 26            27     Co        3200.0       1768.15
# 27            28     Ni        3186.0       1726.15
# 28            29     Cu        2835.0       1357.75
# 29            30     Zn        1180.0        692.88
# 38            39      Y        3609.0       1799.15
# 39            40     Zr        4682.0       2125.15
# 40            41     Nb        5017.0       2741.15
# 41            42     Mo        4912.0       2890.15
# 42            43     Tc        5150.0       2473.15
# 43            44     Ru        4423.0       2523.15
# 44            45     Rh        3968.0       2239.15
# ...

# %%
filter_1 = main_data[["AtomicNumber","Symbol","BoilingPoint","MeltingPoint"]]
first = filter_1[filter_1["AtomicNumber"] >= 21].head(10)
second = filter_1[filter_1["AtomicNumber"] >= 39].head(10)
third = filter_1[filter_1["AtomicNumber"] >= 72].head(10)

x_axis = list(np.arange(0,10))

sns.set_style("darkgrid")

# first["Symbol"].to_string(index = False)

name_1 = list(first["Symbol"])
name_2 = list(second["Symbol"])
name_3 = list(third["Symbol"])

sns.lineplot(x = x_axis, y = first["MeltingPoint"], data = first)
sns.lineplot(x = x_axis, y = second["MeltingPoint"], data = second)
sns.lineplot(x = x_axis, y = third["MeltingPoint"], data = third)

plt.legend(labels = ["21-30","39-48","72-81"], title = "Atomic Number")

# Concatenating 1,2 and 3 datas
#df_concate = pd.concat([first,second,third])
#df_concate
