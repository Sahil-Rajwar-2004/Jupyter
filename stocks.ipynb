# %%
from matplotlib import pyplot as plt
import pandas as pd
import pandas_datareader as pdr
import seaborn as sns

# %%
company = ["GOOGL","AMZN","TSLA","MSFT","NFLX"]

data = pdr.get_data_yahoo(company, start = "2019-01-01")["Close"]
data
# Out:
# Symbols           GOOGL         AMZN        TSLA        MSFT        NFLX
# Date
# 2018-12-31  1044.959961  1501.969971   66.559998  101.570000  267.660004
# 2019-01-02  1054.680054  1539.130005   62.023998  101.120003  267.660004
# 2019-01-03  1025.469971  1500.280029   60.071999   97.400002  271.200012
# 2019-01-04  1078.069946  1575.390015   63.537998  101.930000  297.570007
# 2019-01-07  1075.920044  1629.510010   66.991997  102.059998  315.339996
# ...                 ...          ...         ...         ...         ...
# 2022-05-02  2331.659912  2490.000000  902.940002  284.470001  199.460007
# 2022-05-03  2346.679932  2485.070068  909.250000  281.779999  199.869995
# 2022-05-04  2445.219971  2518.570068  952.619995  289.980011  204.009995
# 2022-05-05  2330.110107  2328.139893  873.280029  277.350006  188.320007
# 2022-05-06  2314.929932  2295.449951  865.650024  274.730011  180.970001
#
# [845 rows x 5 columns]

# %%
plt.figure(figsize = (12,8))
sns.set_style("darkgrid")

plt.plot(data.GOOGL)
plt.plot(data.MSFT)
plt.plot(data.AMZN)
plt.plot(data.NFLX)
plt.plot(data.TSLA)
plt.legend(loc = "best", title = "Companies", labels = ["Google","Microsoft","Amazon","Netflix","Tesla"])

# %%
google = pdr.get_data_yahoo("GOOGL")
google["High"]
# Out:
# Date
# 2017-05-08     960.989990
# 2017-05-09     962.200012
# 2017-05-10     956.710022
# 2017-05-11     957.989990
# 2017-05-12     957.979980
#                  ...
# 2022-05-02    2334.909912
# 2022-05-03    2368.840088
# 2022-05-04    2457.090088
# 2022-05-05    2420.780029
# 2022-05-06    2351.429932
# Name: High, Length: 1260, dtype: float64
